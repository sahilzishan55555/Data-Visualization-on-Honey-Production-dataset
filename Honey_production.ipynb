# %% [markdown]
# # PART II: Data Visualization on Honey Production dataset using seaborn and matplotlib libraries.

# %% [markdown]
# # 1. Import required libraries and read the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style
plt.style.use("classic")
# %matplotlib inline

# %%
data = pd.read_csv("C://Users//sahil//Downloads//honeyproduction.csv")
dataframe = pd.DataFrame(data)
dataframe
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
dataframe.shape  #This code is used to check the shape of the dataframe and to get the total number of rows and columns
# Out:
# (626, 8)

# %%
dataframe.head(15)  #This code is used to get the top 15 rows as sample
# Out:
#    state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0     AL   16000.0           71   1136000.0    159000.0        0.72
# 1     AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2     AR   53000.0           65   3445000.0   1688000.0        0.59
# 3     CA  450000.0           83  37350000.0  12326000.0        0.62
# 4     CO   27000.0           72   1944000.0   1594000.0        0.70
# 5     FL  230000.0           98  22540000.0   4508000.0        0.64
# 6     GA   75000.0           56   4200000.0    307000.0        0.69
# 7     HI    8000.0          118    944000.0     66000.0        0.77
# 8     ID  120000.0           50   6000000.0   2220000.0        0.65
# 9     IL    9000.0           71    639000.0    204000.0        1.19
# 10    IN    9000.0           92    828000.0    489000.0        0.85
# 11    IA   50000.0           78   3900000.0   2301000.0        0.70
# 12    KS   16000.0           46    736000.0    390000.0        0.87
# ...

# %%
dataframe.tail(15)  #This code is for last 15 rows of the dataframe
# Out:
#     state    numcol  yieldpercol   totalprod     stocks  priceperlb  \
# 611    NC   13000.0           39    507000.0   106000.0        3.76
# 612    ND  480000.0           69  33120000.0  5962000.0        1.92
# 613    OH   18000.0           60   1080000.0   410000.0        2.46
# 614    OR   60000.0           32   1920000.0   845000.0        2.16
# 615    PA   16000.0           60    960000.0   269000.0        2.57
# 616    SD  260000.0           63  16380000.0  3604000.0        1.95
# 617    TN    6000.0           61    366000.0    59000.0        2.93
# 618    TX   92000.0           52   4784000.0   718000.0        2.00
# 619    UT   25000.0           38    950000.0   209000.0        1.87
# 620    VT    4000.0           60    240000.0    53000.0        2.39
# 621    VA    4000.0           41    164000.0    23000.0        3.77
# 622    WA   62000.0           41   2542000.0  1017000.0        2.38
# 623    WV    6000.0           48    288000.0    95000.0        2.91
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %% [markdown]
# # 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
total_prodvalue_by_year = dataframe.groupby('year')['prodvalue'].sum()
year= dataframe["year"].unique()
x= total_prodvalue_by_year
y= year
plt.pie(x,labels=y,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
priceperLb = dataframe["priceperlb"]     #price per lb around 1.5 occures maximum times and about 100 times
sns.displot(priceperLb)                  #The most common price is 1.5
plt.title("Distribuation of price per LB")#price per Lb around 4.0 occoures minimum times
plt.xlabel("Price per Lb")                #The least commom price is 4.0
plt.ylabel("Count")                       #The average price would be around between 2 and 2.25
plt.show()

# %% [markdown]
# # 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
a = dataframe["numcol"]
b = dataframe["prodvalue"]
plt.scatter(a,b)
plt.title("Scatter plot of numcol and prodval")
plt.xlabel("numcol")
plt.ylabel("prodvalue")
plt.show()

# %% [markdown]
# _ We can simply say that there is correlation between both the variables
# _ There is positive correlation between both the variables
# _ That simply means that if one variable is increasing then other will also increase
# _ And if one variable is decreasing then other will also decrease
# _ Any impact on any one variable will definitely effect the other variable
# _They both are positively correlated

# %% [markdown]
# # 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
dataframe.dtypes
# Out:
# state           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(dataframe['year'],patch_artist=True,showmeans=True)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Boxplot of Year')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(dataframe['prodvalue'],patch_artist=True,showmeans=True)
plt.title('Boxplot of prodvalue')
plt.ylabel('prodvalue')
plt.show()

# %% [markdown]
# # 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
# Selecting the columns for the pair plot
columns = ['numcol', 'yieldpercol', 'totalprod',  'prodvalue', 'year']

# Creating a new DataFrame with the selected columns
data_for_pairplot = dataframe[columns]

# Plotting the pair plot
sns.pairplot(data_for_pairplot)

# Display the plot
plt.show()

# %% [markdown]
# # 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
# Selecting the columns for correlation analysis
columns = ['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']

# Creating a new DataFrame with the selected columns
data_for_correlation = dataframe[columns]

# Calculating the correlation matrix
correlation_matrix = data_for_correlation.corr()

# Plotting the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Add title and display the plot
plt.title('Correlation Matrix')
plt.show()
